# %% [markdown]
# VORLESUNG: Position \& momentum representation. 21.4 .15
# Let us consider the motion of a quantum particle on a one-dimensonal lune ( $\mathbb{R}$ )
#
# Wi) label the position coordinate $x$ and associate with $x$ a quantum-mechomical operator $\hat{x}$ which is hermitian $\left(x^{\dagger}=x\right)$. A quantum particle with a precisely known position $x$ is dexnibed by a quantunn state $|x\rangle$. If the position is precisely known then $|x\rangle$, by axioms of $Q M$ is an eigenstate of $\hat{x}$ :
#
# $$
# \sum_{\substack{\text { state value of }}}^{\hat{x}|x\rangle}=\underset{\text { state }}{v}|x\rangle \text { en }
# $$
#
#
# We imagine $|x\rangle$ to be a state which is localized (mm some nag) at the position $x$
#
# Let us now consider two different states $|x\rangle$ and $\left|x^{\prime}\right\rangle$, We cut the question: What is the prolalielity to measure $x$ In the state $\left|x^{\prime}\right\rangle$. In quantum mechanics, such prabalitity is determined by the square of the quantum amplitude $\left\langle x \mid x^{\prime}\right\rangle \Rightarrow$ quantum amplitude
# Such that the probability is
#
# $$
# p(x)=\left|\left\langle x \mid x^{\prime}\right\rangle\right|^2
# $$
#
# We know that for $|x\rangle$ and $|x\rangle$ the fallowing hall
# We now calculate $\langle x \mid \alpha\rangle$ :
#
# $$
# \begin{aligned}
# & \hat{x}|x\rangle=\langle\mid x\rangle \\
# & \hat{x}\left|x^{\prime}\right\rangle=x^{\prime}|x\rangle \quad \Leftarrow \\
# & \left\langle x^{\prime}\right| x^{+}=\left\langle x^{\prime}\right| x^{\prime} \\
# & \downarrow \\
# & \left(x^{+}=x\right) \\
# & \left\langle x^{\prime}\right| \hat{x}=x^{\prime}\left\langle x^{\prime}\right|
# \end{aligned}
# $$
#
#
# If we mow take the imper product we obtain
#
# $$
# \begin{aligned}
# & \left\langle x^{\prime}\right| \hat{x}|x\rangle=x^{\prime}\left\langle x^{\prime} \mid x\right\rangle \\
# & x\left\langle x^{\prime} \mid x\right\rangle=x^{\prime}\left\langle x^{\prime} \mid x\right\rangle \\
# & \left(x-x^{\prime}\right)\left\langle x^{\prime} \mid x\right\rangle=0
# \end{aligned}
# $$
#
#
# From this expression wee conclude that:
#
# $$
# \left\langle x^{\prime} \mid x\right\rangle= \begin{cases}0 & \text { if } x \neq x^{\prime} \\ ? & \text { if } x=x^{\prime}\end{cases}
# $$
#
#
# That meows that $|x\rangle$ and $\left|x^{\prime}\right\rangle$ are mutually orthogonal for those cases when $x \neq x^{\prime}$. This is a general property of a hermition operator.
# What happens in the case $x^{\prime}=x$. In that case $\langle x \mid x\rangle$ does not have to home the value 0 but is un fact infinite We require from the position eigenstates to be complete
#
# $$
# \int d x|x\rangle\langle x|=\hat{I}
# $$
#
#
# For any state vector $|\psi\rangle$ wire can wirtio
#
# $$
# \begin{aligned}
# & |\psi\rangle=\hat{I}|\psi\rangle=\int_{\text {to }} d x^{\prime}\left|x^{\prime}\right\rangle\left\langle x^{\prime} \mid \psi\right\rangle \\
# & \text { this leads }
# \end{aligned}
# $$
#
# (a) de define
#
# $$
# \begin{aligned}
# \langle x \mid \psi\rangle & =\int d x^{\prime}\left\langle x^{\prime} \mid x\right\rangle\left\langle x^{\prime} \mid \psi\right\rangle \\
# \langle x \mid \psi\rangle & =\psi(x) \\
# \left\langle x^{\prime} \mid \psi\right\rangle & =\psi\left(x^{\prime}\right)
# \end{aligned}
# $$
#
# so that the relation reads
#
# $$
# \begin{aligned}
# & \psi(x)=\int d x^{\prime} \underbrace{v^{\prime}|x\rangle} \psi(i) \\
# & \delta\left(x, x^{\prime}\right)=\left\langle x^{\prime} \mid x\right\rangle \\
# & \psi^{\prime}(x)=\int d x^{\prime} \delta \delta\left(x^{\prime}, x\right) \psi\left(x^{\prime}\right)
# \end{aligned}
# $$
#
#
# This should he valid for any $\psi$. In particular it should he valid for $\psi(x)=1$. This allows us to deduce another property of $\langle v \mid x\rangle$
#
# $$
# 1=\int d x^{\prime}\left\langle x^{\prime} \mid x\right\rangle \cdot 1 \rightarrow \int d x^{\prime}\left\langle x^{\prime} \mid x\right\rangle=1
# $$
#
#
# So we deduce the fallowing:
#
# $$
# \begin{aligned}
# & \left\langle x^{\prime}(x\rangle\right\rangle=\left\{\begin{array}{lll}
# 0 & \text { for } & x^{\prime} \neq x \\
# \infty & \text { for } & x^{\prime}=x
# \end{array}\right. \\
# & \int d x^{\prime}\left\langle x^{\prime} \mid x\right\rangle=1
# \end{aligned}
# $$
#
#
# The "function" with that properly is called Dirac's $\delta$-funtr. Stridy spooling such function does nat crest in a mathematical ane, but function seguemen can he defined Artich in some limiting cases behave in such hay. One possibility is to define step functions
#
# $$
# \delta_{\varepsilon}(x)= \begin{cases}0 & |x-x|>\varepsilon \\ \frac{1}{2 \varepsilon} & \left|x-y^{\prime}\right| \leq \varepsilon\end{cases}
# $$
# So we have beamed that the eigenstates af a position operators are normalitiel to the Dirac's $\delta$ function
#
# $$
# \left\langle x^{\prime} \mid x\right\rangle=\delta\left(x-x^{\prime}\right)=\delta\left(x^{\prime}-x\right)
# $$
#
#
# This is a general properify of eigenfunction corresponding to the continues part of the spectrum.
# So we have beamed something ahand the position. In order to do physics with the system we med other dynamical variables. The mod important ane us the momentum.
# The momentum can be introduced in two ways. The first way exploits the analogy with dassical mechomies. This was historically the way harl the obsenables were introduced into quantum mechanics. The second way has mo recourse to dassical mechanics and exploits the fundamental principles of symmetry.
# A symmetry principle is a statement that, when we change a point of view in a certain way, the cans of nature do not change.
# In particular, this means in quantum mechanics that symmetry transformations must not change quantum mechanical probabilitio If a system is in a state $|\psi\rangle$ than the measurement of an observable $\hat{A}$ will give the result $a_i$ with the probability
# where
#
# $$
# \begin{aligned}
# & P_i=\left|\left\langle\phi_i \mid \psi\right\rangle\right|^2 \\
# & \text { eigenstate of } \hat{A} \Rightarrow \hat{A}\left|\phi_i\right\rangle=a_i\left|\phi_i\right\rangle
# \end{aligned}
# $$
#
# Thus, the symmetry transformation must leave $\left|\left\langle\phi_i \mid \psi\right\rangle\right|^2$ inveranant for all choices of $\phi^{\prime} s$ and $\psi^{\prime} s$.
# Now any transformation changes the quantum state. So we associate with a transformation some operator $\hat{U}$ such that
#
# $$
# \begin{aligned}
# & |\psi\rangle \xrightarrow{\text { tranefal }} \\
# & \left|\phi_i\right\rangle \xrightarrow[U]{ }|\psi\rangle \\
# & \left\langle\phi_i\right| \xrightarrow{\downarrow}\left|\phi_i\right\rangle
# \end{aligned}
# $$
#
#
# So if a transformation is to be a symmetry we require that
#
# $$
# \left\langle\phi_i \mid \psi\right\rangle \Rightarrow\left\langle\phi_i\right| \cup^{+} u|\psi\rangle=\left\langle\phi_i \mid \psi\right\rangle
# $$
#
#
# From this it fallows that $U^{+} U=I$ for symmetry transformations. Transformations that have this property are called unitary transformations!
# In the following ne consider special class of symmetries represented by linear unitary operators which are arbitrary dose to $\hat{I}$. Any such operator can le written un the form
#
# $$
# \hat{U}_{\varepsilon}=I+i \varepsilon \hat{T}+\theta\left(\varepsilon^2\right)
# $$
#
#
# From the unitarity it fallers
#
# $$
# \begin{aligned}
# & U^{+} U=I \Rightarrow\left(\hat{I}-i \varepsilon \hat{T}^{+}\right)(I+i \varepsilon \hat{T}+\cdots)=I \\
# & I+i \varepsilon\left(T-T^{+}\right)+\cdots=\underline{I}
# \end{aligned}
# $$
#
#
# From this it follows that:
#
# $$
# T=T^{+}
# $$
#
#
# We see that the presence of infinitesimal symmetry naturally gives wise to Hermitian operators (generators of symmetries!.).
# Since hermitian operators are associated with observables we see that Symmetries are a natural source of physical abservdbls!
#
# In fact, most if not all of the operators representing observables in quantum mechanise are the generators of symmetries !
# translational symmetry
# Wi first consider the translational symmetry. The laws of nature should not change if we shift the engin of our coordinates. Ne define the fallowing operator.
#
# $$
# \hat{T}(\Delta x)|x\rangle=|x+\Delta x\rangle
# $$
#
# continuous parameter
#
# How does the translational operator affect am arbitrary state?
#
# $$
# \begin{aligned}
# \hat{T}(\Delta x)|\psi\rangle & =\hat{T}(\Delta x) \hat{I}|\psi\rangle \\
# & =\int d x^{\prime} \hat{T}(\Delta x)\left|x^{\prime}\right\rangle\left\langle x^{\prime} \mid \psi\right\rangle \\
# & =\int d x^{\prime}\left|x^{\prime}+\Delta x\right\rangle\left\langle x^{\prime} \mid \psi\right\rangle
# \end{aligned}
# $$
#
#
# By projecting onto $\langle x|$
#
# $$
# \begin{aligned}
# & \langle x| \hat{T}(\Delta x)|\psi\rangle=\int_{x^{\prime}+\Delta x=x}^{\int d x^{\prime}}\langle\underbrace{\left\langle x \mid x^{\prime}+\Delta x\right\rangle}\left\langle x^{\prime} \mid \psi\right\rangle \\
# & \begin{array}{c}
# x^{\prime}=x-\Delta x
# \end{array} \\
# & \langle x| \hat{T}(\Delta x)|\psi\rangle=\begin{array}{l}
# \langle\mu-\Delta x \mid \psi\rangle
# \end{array}
# \end{aligned}
# $$
#
#
# Wee see that the application of the $\hat{T}(\Delta x)$ to
#
# He replacement of $x$ m $\langle x \mid y\rangle$ by $x-\Delta x$, leading to $\langle x-\Delta x \mid \psi\rangle$ sauce $\hat{T}(\Delta x)$ is a unitan operator we cam write it as
#
# $$
# \hat{T}(\Delta x)=\hat{I}-2 \Delta x \hat{K} \quad \text { where } \hat{K} \text { a hermitian }
# $$
#
# 1.) Thou loss of generality we cam waste
#
# $$
# \begin{aligned}
# & \hat{T}(\Delta x)=\hat{I}-\frac{i}{\hbar} \Delta x(\hat{K} \hbar) \\
# & \hat{T}(\Delta x)=\hat{I}-\frac{i}{\hbar} \Delta x \hat{P}
# \end{aligned}
# $$
#
#
# The operator $\hat{p}$ is called MOMENTUM! The above operation thus defines the momentum en operator. It remains to be proven that this momentum reduces to the dassical momentum in the dossal limit..
#
# In the following we which to answer the question how does the momentum operator acts on an arbitrary state
# | 4$)^{\prime}$ ?
# Specifically, are ask question: What is $\langle x| \hat{p}|\psi\rangle$ ?
# The quomitity $\langle x| \hat{P}|\psi\rangle$ is a position space representation of $\hat{P}|\psi\rangle$.
#
# We start with.
#
# $$
# \begin{aligned}
# & \langle x| \hat{f}(\Delta x)|\psi\rangle=\langle x-\Delta x \mid \psi\rangle \\
# & \langle x| \hat{I}-\frac{i}{\hbar} \Delta x \hat{P}|\psi\rangle=\langle x-\Delta x \mid \psi\rangle \\
# & \langle x \mid \psi\rangle-\frac{i}{\hbar} \Delta\langle\langle x| \hat{P} \mid \psi\rangle=\langle x-\Delta x \mid \psi\rangle \\
# & \frac{\hbar}{i} \quad \frac{\langle x \mid \psi\rangle-\langle x-\Delta x \mid \psi\rangle}{\Delta x}+\theta(\Delta x)=\langle x| \hat{p}|\psi\rangle
# \end{aligned}
# $$
#
#
# By toking the limit $\Delta x \rightarrow 0$ we see that
#
# $$
# \begin{gathered}
# \langle x| \hat{p}|\psi\rangle=\lim _{\Delta x \rightarrow 0} \frac{\psi(x)-\psi(x-a x)}{\Delta x}=\frac{\hbar}{\Delta x} \frac{\partial}{\partial x}\langle x \mid \psi\rangle \\
# \psi \psi|\hat{p}| \psi\rangle=\frac{\hbar}{i} \frac{\partial}{\partial x}\langle x \mid \psi\rangle \\
# \text { or } \\
# \langle x| \hat{p}|\psi\rangle \Rightarrow \frac{\hbar}{i} \frac{\partial}{\partial x} \psi(x)
# \end{gathered}
# $$
#
#
# Thus, we cam say that applying the mamentiun operator in the position representation corresponds to
#
# $$
# \frac{\hbar}{i} \frac{\partial}{\partial x}
# $$
#
# which should be familiar from a basic quantum mechomies cause.
# In the following are wish to answer the question if $\hat{x}$ and $\hat{p}$ can le simultaneously preciely fanon. For this purpose we need to calculate the commutator $[\hat{x}, \hat{P}]$.
# We start by calculating $[\hat{x}, \hat{T}(\Delta x)]$.
# Take any state $|\psi\rangle$ and apply the commutator:
#
# $$
# \begin{aligned}
# & {[\hat{x}, \hat{T}(\Delta x)]|\psi\rangle=\hat{x} \hat{T}(\Delta x)|\psi\rangle-\hat{T}(\Delta x) \hat{x}|\psi\rangle } \\
# {\left[\hat{x_1} \hat{T}(\Delta x)\right]|\psi\rangle=} & \left.\int d x^{\prime}\left|x^{\prime}\right\rangle\left\langle x^{\prime}\right| \hat{x} \hat{x}(\Delta x)\left|x^{\prime}\right\rangle\left\langle x^{\prime} \mid \psi\right\rangle-\hat{T}(\Delta x) \hat{x}\left|x^{\prime}\right\rangle\left\langle x^{\prime}\right\rangle\left\langle x^{\prime} \mid \psi\right\rangle\right) \\
# = & \int d x^{\prime} \hat{x}\left|x^{\prime}+\Delta x\right\rangle\left\langle x^{\prime} \mid \psi\right\rangle-x^{\prime} \hat{T}(\Delta x)\left|x^{\prime}\right\rangle\left(x^{\prime}|\psi\rangle\right) \\
# = & \int d x^{\prime}\left(x^{\prime}+\Delta x\right)\left|x^{\prime}+\Delta x\right\rangle\langle x \mid \psi\rangle-x^{\prime}\left|x^{\prime}+\Delta x\right\rangle\left\langle x^{\prime} \mid \psi\right\rangle \\
# = & \Delta x \int d x^{\prime}\left|x^{\prime}+\Delta x\right\rangle\left\langle x^{\prime} \mid \psi\right\rangle \\
# = & \Delta x \hat{T}(\Delta x) \int d x^{\prime}\left|x^{\prime}\right\rangle\left\langle x^{\prime} \mid \psi\right\rangle \\
# & =\Delta x \hat{T}(\Delta x)|\psi\rangle
# \end{aligned}
# $$
#
# Since this expression will be valid for all $|\psi\rangle$ we infer.
# By dividing with $\quad[\hat{x}, \hat{T}(\Delta x)]=\hat{T}(\Delta x) \cdot \Delta x$
#
# $$
# \frac{1}{\Delta x}[\hat{x}, \hat{T}(\Delta x)]=T(\Delta x)
# $$
#
#
# Now we remember the relation: $\hat{T}(\Delta x)=\hat{I}-\hat{i} \Delta x \hat{P}$ and insert in the abele expression
#
# $$
# \begin{aligned}
# & \frac{1}{\Delta x}[\hat{x}, \hat{T}(\Delta x)]=\frac{1}{\Delta x}\left[\hat{x}, I-\frac{i}{\hbar} \Delta x \hat{P}\right]=I-\frac{i}{\hbar} \Delta x \hat{P} \\
# & \underbrace{\frac{1}{\Delta x}[\hat{x}, \hat{I}]-\frac{i}{\hbar}[\hat{x}, \hat{P}]=I-\frac{1}{\hbar} \Delta x \hat{P}+\cdots}_0 \\
# & \underbrace{\hbar \hat{x}}_0, \hat{P}]=-\frac{\hbar}{i}+\Delta x \hat{P}+\theta\left(\Delta x^2\right)+\cdots
# \end{aligned}
# $$
#
# $\lim$ leads to
# $\Delta x \rightarrow 0$
#
# $$
# [\hat{x}, \hat{p}]=i \hbar
# $$
#
#
# We have shown that $\hat{x}$ and $\hat{p}$ are incompatible observalles! Historically, this relation has been found by Max Born right after Weer Heisenberg has introduced the matrix mechanics.
# The moncommutability of $\hat{X}$ and $\hat{P}$ means that there are no simultaneous eigenfunctions of $\hat{X}$ and $\hat{P}$. There is no such thing as $|x, p\rangle$ so that
#
# $$
# \begin{aligned}
# & \hat{x}|x, p\rangle=x|x, p\rangle \\
# & \hat{p}|x, p\rangle=p|x, p\rangle
# \end{aligned}
# $$
#
#
# But if $\hat{P}$ is an observable, what ane the eigenstates of $\hat{p}$ ?
#
# $$
# \hat{p}|p\rangle=p|p\rangle
# $$
#
#
# Such eigenstate represents a physical state with a precisely determined momentum.
#
# How does the momentum eigenstate representation?
#
# $$
# \langle\hat{x}| \hat{p}|p\rangle=\frac{\hbar}{i} \frac{\partial}{\partial x}\langle x \mid p\rangle=p\langle x \mid p\rangle
# $$
#
#
# This is a first order differential equation which can le easily solved
#
# $$
# \langle x \mid p\rangle=\sqrt[N]{ } e^{\mid p x / \hbar}
# $$
#
# $\mathcal{N}$ is a normalization constant. The problem is that the momentum eigenstates comsat be moralized in a usual sense such that $\quad\langle p \mid p\rangle=1$.
# Instead in the analogy with position eigenstates we require the momention eigenstat's to be normalised such the
#
# $$
# \begin{aligned}
# & \left\langle p^{\prime} \mid p\right\rangle=\delta\left(p^{\prime}-p\right) \\
# & \left.|x|^2 \int d x e^{i\left(p-p^{\prime}\right) x / \hbar}=\delta\left(p^{\prime}-p\right) \int d p{ }^{\prime}\right) \\
# & |J|^2 \int d p^{\prime} d x c^{\prime}\left(p-p^{\prime}\right) x / \hbar=1
# \end{aligned}
# $$
#
#
# In order to calculate the abe integral we first quantize the momentum, This can be achived by imposing periodic boundary conditions. This is equirdent to replacing an infinite lime by a circle with some ciroungence.
#
# Imposing periodic boundary condition means that
# spirally $\quad \psi(x+L)=\psi(x)$
# for a momentum w eigenstate this means that
#
# $$
# \begin{aligned}
# & \langle x \mid p\rangle=\langle x+L / p\rangle \\
# & e^{i p x / h}=e^{i p(x+L) / \hbar} \Rightarrow e^{i p L / \hbar}=1
# \end{aligned}
# $$
#
#
# From this it follows
#
# $$
# \frac{p L}{\hbar}=2 \pi n \Rightarrow p_n=\frac{2 \pi n}{L} \hbar
# $$
#
#
# Thus for a partide on a circle, the momentum n is quantized , and the momentum aigenstates read
#
# $$
# \left\langle x \mid p_n\right\rangle=N e^{i \frac{2 \pi n}{t} \hbar x}
# $$
#
#
# Such states are normalizable in a usual sense!
#
# $$
# \int_0^L d x\left\langle p_a \mid x\right\rangle\left\langle x \mid p_n\right\rangle=1 \Rightarrow N^2 L=1 \Rightarrow N=\frac{1}{\sqrt{L}}
# $$
#
#
# Thus the states:
#
# $$
# \left\langle x \mid p_n\right\rangle=\frac{1}{\sqrt{L}} e^{i \frac{2 \pi n \hbar}{L} x}
# $$
#
# are orthonormal
#
# $$
# \left\langle p_m \mid p_n\right\rangle=\int_{-\frac{L}{2}}^{\frac{L}{L}} d x\left\langle p_m \mid x\right\rangle\left\langle x \mid p_n\right\rangle=\delta_{m \omega}
# $$
#
#
# From
# $\left\langle p_m \mid p_n\right\rangle=\delta_{m n}$ it fallows
#
# $$
# \begin{aligned}
# & \sum_m\left\langle p_m \mid p_n\right\rangle=\sum_m \delta_{m n}=1 \\
# & \sum_m \int_{-\frac{L}{2}}^{\frac{L}{2}} d x\left\langle p_m \mid x\right\rangle\left\langle x \mid p_n\right\rangle=1
# \end{aligned}
# $$
#
#
# $$
# \begin{aligned}
# & \sum_m \int_{-L}^{L / L} d x \frac{1}{L} e^{-\frac{i 2 \pi(m-n) \hbar x}{L}}=1 \\
# & \frac{1}{2 \pi \hbar} \sum_m^2 \frac{2 \pi \hbar}{L} \int_{-\frac{L}{2}}^{\frac{L}{2}} e^{-i} \frac{2 \pi \hbar}{L}(m-n) \times=1 \\
# & \text { Fur } \quad L \rightarrow \infty \quad \Delta p=\frac{2 \pi t}{L} \Rightarrow 0 \\
# & \frac{1}{2 \pi \hbar} \iint d p^{\prime} d x e^{i\left(p^{\prime}-p\right) x / \hbar}=1 \\
# & \int_{-\infty}^{+\infty} d p^{\prime}\left[\frac{1}{2 \pi \hbar} \int_{-\infty}^{+\infty} e^{i^{\prime}\left(p^{\prime}-p\right) / \hbar} d x\right]=1 \\
# & \delta\left(p^{\prime}-p\right)=\frac{1}{2 \pi \hbar} \int d x e^i(p-p) x / \hbar \\
# & \delta\left(p^{\prime}-p\right)=\int d x \frac{e^{i p^{\prime} x / \hbar}}{\sqrt{2 \pi \hbar}} \frac{e^{-i p x / \hbar}}{\sqrt{2 \pi \hbar}} \\
# & \left\langle x \mid p^{\prime}\right\rangle \quad\langle p \mid x\rangle
# \end{aligned}
# $$
#
#
# So we can identify:
#
# $$
# \left\langle\langle x \mid p\rangle=\frac{1}{\sqrt{2 \pi \hbar}} e^{i p x / \hbar}\right.
# $$
#
#
# This is a fundamental relation allowing us to switch between the position and the momentum representation for amy quantum state!
#
# Position and Momentum Representation
# We have now two operators $\hat{x}$ and $\hat{p}$ whose corresponding eigenfunction build a complete sets
#
# $$
# \begin{aligned}
# & \hat{I}=\int d x|x\rangle\langle x| \\
# & \hat{I}=\int d p|p\rangle\langle p|
# \end{aligned}
# $$
#
#
# We can now represent any quantum state either in the position or on the momentum basis
#
# $$
# \begin{aligned}
# & |\psi\rangle=\int d x|x\rangle\langle x \mid \psi\rangle \\
# & |\psi\rangle=\int d p|p\rangle\langle p \mid \psi\rangle
# \end{aligned}
# $$
#
# $\langle x \mid \psi\rangle$ is defined as a position representation of the quanturn state $|\psi\rangle$ and it is usually denoted by $\psi(x)$.
# $\langle p \mid \psi\rangle$ is defined as a momentum representation of the quantum/ state $|\psi\rangle$ and is denoted by $\phi(p)$.
# We mow answer the following question. Given $\psi(x)$, how can we get $\phi(p)$ and vice vera?
#
# $$
# \begin{aligned}
# \phi(p)=\langle p \mid \psi\rangle & =\langle p| \hat{I}|\psi\rangle=\int d x\langle p \mid x\rangle\langle x \mid \psi\rangle \\
# & =\frac{1}{\sqrt{2 \pi h}} \int d x e^{-i p x / \hbar} \psi(x)
# \end{aligned}
# $$
#
#
# Thus,
#
# $$
# \phi(p)=\frac{1}{\sqrt{2 \pi \hbar}} \int_{-\infty}^{+\infty} \psi(x) e^{-i p x / \hbar}
# $$
#
#
# The transformation works also in the oposite direction!
#
# $$
# \begin{aligned}
# \psi(x)=\langle x \mid \psi\rangle & =\langle x| \hat{I}|\psi\rangle=\int d p\langle x \mid p\rangle\langle p \mid \psi\rangle \\
# & =\frac{1}{\sqrt{2 \pi \hbar}} \int_{-\infty}^{+\infty} d p \phi(p) e^{i p^x / \hbar}
# \end{aligned}
# $$
#
# So we obtain the
#
# $$
# \begin{aligned}
# & \phi(p)=\frac{1}{\sqrt{2 \pi \hbar}} \int_{-\infty}^{+\infty} \psi(x) e^{-i p x / \hbar} d x \\
# & \psi(x)=\frac{1}{\sqrt{2 \pi \hbar}} \int_{-\infty}^{+\infty} \phi(p) e^{i p^x / \hbar} d p
# \end{aligned}
# $$
#
#
# Example:
# We consider a step function:
#
# $$
# \psi(x)= \begin{cases}0 & |x|>\frac{1}{2} a \\ c & |x| \leqslant \frac{1}{2} a\end{cases}
# $$
#
#
# We first normalise the function such that.
#
# $$
# \begin{aligned}
# & \int_{-\infty}^{+\infty}|\psi(x)|^2 d x=1 \\
# & \int_{-\frac{1}{2} a}^{+\frac{1}{2} a}|c|^2 d x=1 \Rightarrow|a|^2 \cdot a=1 \Rightarrow|c|=\frac{1}{\sqrt{a}}
# \end{aligned}
# $$
#
#
# Thus, moralized function reads
#
# $$
# \psi(x)= \begin{cases}0 & |x|>\frac{1}{2} a \\ \frac{1}{\sqrt{a}} & |x| \leqslant \frac{1}{2} a\end{cases}
# $$
#
# In the joucowing we calculate the momentum space representation of such quantum state
#
# $$
# \begin{aligned}
# & \langle p \mid \psi\rangle=\int d x\langle p \mid x\rangle\langle x \mid \psi\rangle \\
# & \frac{1}{\sqrt{2 \pi \hbar}} e^{-i p x / \hbar} \\
# & =\frac{1}{\sqrt{2 \pi \hbar}} \int_{-\infty}^{+\infty} d x \psi(x) e^{-i p x / \hbar} \\
# & =\frac{1}{\sqrt{2 \pi \hbar}} \int_{-\infty}^{+\infty} d x \psi(x) e^{-i p x / \hbar} \\
# & =\frac{1}{\sqrt{2 \pi \hbar}} \int_{-\frac{a}{2}}^{\frac{a}{2}} d x \frac{1}{\sqrt{a}}-e^{i p x / t} \\
# & =\frac{1}{\sqrt{2 a \pi \hbar}}\left[\left.\frac{-\hbar}{i p} e^{-i p x / \hbar}\right|_{-a / 2} ^{a / 2}\right] \\
# & =\frac{2 \hbar}{\sqrt{2 a \pi \hbar}}\left[\frac{e^{i p a / 2 \hbar}-e^{-i p a / 2 \hbar}}{2 i p}\right] \\
# & =\frac{2 \hbar}{\sqrt{2 a \pi t}} \cdot \frac{1}{p} \cdot \sin \left(\frac{p a}{2 \hbar}\right) \\
# & =\sqrt{\frac{2 \hbar}{a \pi}} \cdot \frac{1}{p} \sin \left(\frac{p a}{2 \hbar}\right)
# \end{aligned}
# $$
#
# Ne see that the state
# between $-\frac{a}{2}$ and $\frac{a}{2}$. In the momentum space, the same state is mat perfectly localized. However, we can roughly define the width of the state on the momentum spare as a separation between the first two zero pants
#
# $$
# \begin{aligned}
# & \sin \left(\frac{p a}{2 \hbar}\right)=0 \\
# & \frac{p a}{2 \hbar}= \pm \frac{\pi}{2} \\
# & p= \pm \frac{\pi \hbar}{a}
# \end{aligned}
# $$
#
#
# So we see that $\Delta p \sim \frac{2 \pi \hbar}{a}$
# From this we can derive a special form of the Heisenberg's uncertainty relation:
#
# $$
# \Delta x \cdot \Delta p=\alpha \cdot \frac{2 \pi \hbar}{a}=2 \pi \hbar
# $$
#
#
# Which tells us that the product of uncerntannties in $x$ and $p$ is of the order of $\hbar$ !
#
# $$
# \Delta x \Delta p \sim t
# $$
#
#
# Example 2
# How does the ground state of a harmonic oscillator look like?

# %% [markdown]
# ## Position and momentum representation
#
# Let us consider the motion of a quantum particle constrained to a one-dimensional line, where the position coordinate is continuous and labeled by real numbers ($x \in \mathbb{R}$).
#
# According to the principles of quantum mechanics, we associate each position $x$ with a quantum-mechanical operator $\hat{x}$ that is Hermitian, satisfying $\hat{x}^\dagger = \hat{x}$. Since we are working in one spatial dimension, the operator $\hat{x}$ acts on a domain that is a subset of a Hilbert space—typically the space of square-integrable functions.
#
# A quantum particle whose position is known exactly to be $x$ is described by a quantum state $|x\rangle$. By the postulates of quantum mechanics, this state must be an eigenstate of the position operator $\hat{x}$, with eigenvalue $x$:
#
# $$
# \hat{x} |x\rangle = x |x\rangle
# $$

# %% [markdown]
# We imagine the $|x\rangle$ to be a state which is sharpely localized at the position $x$
#
# Let us now consider two different states $|x\rangle$and$\left|x^{\prime}\right\rangle$.
# We can now ask the following question: What is the probability to measure $x$In the state$\left|x^{\prime}\right\rangle$?
#
# In quantum mechanics, such probability is determined by the square of the quantum amplitude $\langle x| x^{\prime}\rangle$.
# From the amplitude we get the probability by:
#
# $$
# p(x)=\left|\left\langle x \mid x^{\prime}\right\rangle\right|^2
# $$
#
# We know that for two different eigenstates $|x\rangle$ and$|x\rangle$ the fallowing holds since
# they are both eigenstates of $\hat{x}$-Operator:
#
#
# $$
# & \hat{x}|x\rangle=x\langle x\rangle \\
#
#
# & \downarrow \\
#
# & \left(x^{+}=x\right) \\
#
# & \left\langle x^{\prime}\right| \hat{x}=x^{\prime}\left\langle x^{\prime}\right|
# $$

# %% [markdown]
# If we mow take the imper product we obtain
#
# $$
# $$
# & \left\langle x^{\prime}\right| \hat{x}|x\rangle=x^{\prime}\left\langle x^{\prime} \mid x\right\rangle \\
#
# & x\left\langle x^{\prime} \mid x\right\rangle=x^{\prime}\left\langle x^{\prime} \mid x\right\rangle \\
#
# & \left(x-x^{\prime}\right)\left\langle x^{\prime} \mid x\right\rangle=0
# $$
# $$
#
#
# From this expression wee conclude that:
#
# $$
# \left\langle x^{\prime} \mid x\right\rangle=
# $$
# 0 & \text { if } x \neq x^{\prime} \\
#  ? & \text { if } x=x^{\prime}
# $$
# $$
#
#
# That meows that $|x\rangle$and$\left|x^{\prime}\right\rangle$are mutually orthogonal for those cases when$x \neq x^{\prime}$. This is a general property of a hermition operator.
# What happens in the case $x^{\prime}=x$. In that case $\langle x \mid x\rangle$ does not have to home the value 0 but is un fact infinite We require from the position eigenstates to be complete
#
# $$
# \int d x|x\rangle\langle x|=\hat{I}
# $$
#
#
# For any state vector $|\psi\rangle$ wire can wirtio
#
# $$
# $$
# & |\psi\rangle=\hat{I}|\psi\rangle=\int_{\text {to }} d x^{\prime}\left|x^{\prime}\right\rangle\left\langle x^{\prime} \mid \psi\right\rangle \\
#
# & \text { this leads }
# $$
# $$
#
# (a) de define
#
# $$
# $$
# \langle x \mid \psi\rangle & =\int d x^{\prime}\left\langle x^{\prime} \mid x\right\rangle\left\langle x^{\prime} \mid \psi\right\rangle \\
#
# \langle x \mid \psi\rangle & =\psi(x) \\
#
# \left\langle x^{\prime} \mid \psi\right\rangle & =\psi\left(x^{\prime}\right)
# $$
# $$
#
# so that the relation reads
#
# $$
# $$
# & \psi(x)=\int d x^{\prime} \underbrace{v^{\prime}|x\rangle} \psi(i) \\
# & \delta\left(x, x^{\prime}\right)=\left\langle x^{\prime} \mid x\right\rangle \\
# & \psi^{\prime}(x)=\int d x^{\prime} \delta \delta\left(x^{\prime}, x\right) \psi\left(x^{\prime}\right)
# $$
# $$
#
#
# This should he valid for any $\psi$. In particular it should he valid for $\psi(x)=1$. This allows us to deduce another property of $\langle v \mid x\rangle
# $$
#
# $$
# 1=\int d x^{\prime}\left\langle x^{\prime} \mid x\right\rangle \cdot 1 \rightarrow \int d x^{\prime}\left\langle x^{\prime} \mid x\right\rangle=1
# $$
#
#
# So we deduce the fallowing:
#
# $$
# $$
# & \left\langle x^{\prime}(x\rangle\right\rangle=\left\{
# $$
# {lll}
# 0 & \text { for } & x^{\prime} \neq x \\
#
# \infty & \text { for } & x^{\prime}=x
# $$
# \right. \\
#
# & \int d x^{\prime}\left\langle x^{\prime} \mid x\right\rangle=1
# $$
# $$
#
#
# The "function" with that properly is called Dirac's $\delta$-funtr. Stridy spooling such function does nat crest in a mathematical ane, but function seguemen can he defined Artich in some limiting cases behave in such hay. One possibility is to define step functions
#
# $$
# \delta_{\varepsilon}(x)=
# $$
# 0 & |x-x|>\varepsilon \\
#  \frac{1}{2 \varepsilon} & \left|x-y^{\prime}\right| \leq \varepsilon
# $$
# $$
# So we have beamed that the eigenstates af a position operators are normalitiel to the Dirac's $\delta$ function
#
# $$
# \left\langle x^{\prime} \mid x\right\rangle=\delta\left(x-x^{\prime}\right)=\delta\left(x^{\prime}-x\right)
# $$
#
#
# This is a general properify of eigenfunction corresponding to the continues part of the spectrum.
# So we have beamed something ahand the position. In order to do physics with the system we med other dynamical variables. The mod important ane us the momentum.
# The momentum can be introduced in two ways. The first way exploits the analogy with dassical mechomies. This was historically the way harl the obsenables were introduced into quantum mechanics. The second way has mo recourse to dassical mechanics and exploits the fundamental principles of symmetry.
# A symmetry principle is a statement that, when we change a point of view in a certain way, the cans of nature do not change.
# In particular, this means in quantum mechanics that symmetry transformations must not change quantum mechanical probabilitio If a system is in a state $|\psi\rangle$than the measurement of an observable$\hat{A}$will give the result$a_i$ with the probability
# where
#
# $$
# $$
# & P_i=\left|\left\langle\phi_i \mid \psi\right\rangle\right|^2 \\
#
# & \text { eigenstate of } \hat{A} \Rightarrow \hat{A}\left|\phi_i\right\rangle=a_i\left|\phi_i\right\rangle
# $$
# $$
#
# Thus, the symmetry transformation must leave $\left|\left\langle\phi_i \mid \psi\right\rangle\right|^2$inveranant for all choices of$\phi^{\prime} s$and$\psi^{\prime} s$.
# Now any transformation changes the quantum state. So we associate with a transformation some operator $\hat{U}$ such that
#
# $$
# $$
# & |\psi\rangle \xrightarrow{\text { tranefal }} \\
#
# & \left|\phi_i\right\rangle \xrightarrow[U]{ }|\psi\rangle \\
#
# & \left\langle\phi_i\right| \xrightarrow{\downarrow}\left|\phi_i\right\rangle
# $$
# $$
#
#
# So if a transformation is to be a symmetry we require that
#
# $$
# \left\langle\phi_i \mid \psi\right\rangle \Rightarrow\left\langle\phi_i\right| \cup^{+} u|\psi\rangle=\left\langle\phi_i \mid \psi\right\rangle
# $$
#
#
# From this it fallows that $U^{+} U=I$for symmetry transformations. Transformations that have this property are called unitary transformations!
# In the following ne consider special class of symmetries represented by linear unitary operators which are arbitrary dose to$\hat{I}$. Any such operator can le written un the form
#
# $$
# \hat{U}_{\varepsilon}=I+i \varepsilon \hat{T}+\theta\left(\varepsilon^2\right)
# $$
#
#
# From the unitarity it fallers
#
# $$
# $$
# & U^{+} U=I \Rightarrow\left(\hat{I}-i \varepsilon \hat{T}^{+}\right)(I+i \varepsilon \hat{T}+\cdots)=I \\
#
# & I+i \varepsilon\left(T-T^{+}\right)+\cdots=\underline{I}
# $$
# $$
#
#
# From this it follows that:
#
# $$
# T=T^{+}
# $$
#
#
# We see that the presence of infinitesimal symmetry naturally gives wise to Hermitian operators (generators of symmetries!.).
# Since hermitian operators are associated with observables we see that Symmetries are a natural source of physical abservdbls!
#
# In fact, most if not all of the operators representing observables in quantum mechanise are the generators of symmetries !
# translational symmetry
# Wi first consider the translational symmetry. The laws of nature should not change if we shift the engin of our coordinates. Ne define the fallowing operator.
#
# $$
# \hat{T}(\Delta x)|x\rangle=|x+\Delta x\rangle
# $$
#
# continuous parameter
#
# How does the translational operator affect am arbitrary state?
#
# $$
# $$
# \hat{T}(\Delta x)|\psi\rangle & =\hat{T}(\Delta x) \hat{I}|\psi\rangle \\
#
# & =\int d x^{\prime} \hat{T}(\Delta x)\left|x^{\prime}\right\rangle\left\langle x^{\prime} \mid \psi\right\rangle \\
#
# & =\int d x^{\prime}\left|x^{\prime}+\Delta x\right\rangle\left\langle x^{\prime} \mid \psi\right\rangle
# $$
# $$
#
#
# By projecting onto $\langle x|
# $$
#
# $$
# $$
# & \langle x| \hat{T}(\Delta x)|\psi\rangle=\int_{x^{\prime}+\Delta x=x}^{\int d x^{\prime}}\langle\underbrace{\left\langle x \mid x^{\prime}+\Delta x\right\rangle}\left\langle x^{\prime} \mid \psi\right\rangle \\
#
# &
# $$
# {c}
# x^{\prime}=x-\Delta x
# $$
#  \\
#
# & \langle x| \hat{T}(\Delta x)|\psi\rangle=
# $$
# {l}
# \langle\mu-\Delta x \mid \psi\rangle
# $$
# $$
# $$
#
#
# Wee see that the application of the $\hat{T}(\Delta x)$to
#
# He replacement of$x$m$\langle x \mid y\rangle$by$x-\Delta x$, leading to $\langle x-\Delta x \mid \psi\rangle$sauce$\hat{T}(\Delta x)$ is a unitan operator we cam write it as
#
# $$
# \hat{T}(\Delta x)=\hat{I}-2 \Delta x \hat{K} \quad \text { where } \hat{K} \text { a hermitian }
# $$
#
# 1.) Thou loss of generality we cam waste
#
# $$
# $$
# & \hat{T}(\Delta x)=\hat{I}-\frac{i}{\hbar} \Delta x(\hat{K} \hbar) \\
#
# & \hat{T}(\Delta x)=\hat{I}-\frac{i}{\hbar} \Delta x \hat{P}
# $$
# $$
#
#
# The operator $\hat{p}$ is called MOMENTUM! The above operation thus defines the momentum en operator. It remains to be proven that this momentum reduces to the dassical momentum in the dossal limit..
#
# In the following we which to answer the question how does the momentum operator acts on an arbitrary state
# | 4$)^{\prime}$?
# Specifically, are ask question: What is$\langle x| \hat{p}|\psi\rangle$?
# The quomitity$\langle x| \hat{P}|\psi\rangle$is a position space representation of$\hat{P}|\psi\rangle$.
#
# We start with.
#
# $$
# $$
# & \langle x| \hat{f}(\Delta x)|\psi\rangle=\langle x-\Delta x \mid \psi\rangle \\
#
# & \langle x| \hat{I}-\frac{i}{\hbar} \Delta x \hat{P}|\psi\rangle=\langle x-\Delta x \mid \psi\rangle \\
#
# & \langle x \mid \psi\rangle-\frac{i}{\hbar} \Delta\langle\langle x| \hat{P} \mid \psi\rangle=\langle x-\Delta x \mid \psi\rangle \\
#
# & \frac{\hbar}{i} \quad \frac{\langle x \mid \psi\rangle-\langle x-\Delta x \mid \psi\rangle}{\Delta x}+\theta(\Delta x)=\langle x| \hat{p}|\psi\rangle
# $$
# $$
#
#
# By toking the limit $\Delta x \rightarrow 0$ we see that
#
# $$
# $$
# \langle x| \hat{p}|\psi\rangle=\lim _{\Delta x \rightarrow 0} \frac{\psi(x)-\psi(x-a x)}{\Delta x}=\frac{\hbar}{\Delta x} \frac{\partial}{\partial x}\langle x \mid \psi\rangle \\
#
# \psi \psi|\hat{p}| \psi\rangle=\frac{\hbar}{i} \frac{\partial}{\partial x}\langle x \mid \psi\rangle \\
#
# \text { or } \\
#
# \langle x| \hat{p}|\psi\rangle \Rightarrow \frac{\hbar}{i} \frac{\partial}{\partial x} \psi(x)
# $$
# $$
#
#
# Thus, we cam say that applying the mamentiun operator in the position representation corresponds to
#
# $$
# \frac{\hbar}{i} \frac{\partial}{\partial x}
# $$
#
# which should be familiar from a basic quantum mechomies cause.
# In the following are wish to answer the question if $\hat{x}$and$\hat{p}$can le simultaneously preciely fanon. For this purpose we need to calculate the commutator$[\hat{x}, \hat{P}]$.
# We start by calculating $[\hat{x}, \hat{T}(\Delta x)]$.
# Take any state $|\psi\rangle$ and apply the commutator:
#
# $$
# $$
# & {[\hat{x}, \hat{T}(\Delta x)]|\psi\rangle=\hat{x} \hat{T}(\Delta x)|\psi\rangle-\hat{T}(\Delta x) \hat{x}|\psi\rangle } \\
#
# {\left[\hat{x_1} \hat{T}(\Delta x)\right]|\psi\rangle=} & \left.\int d x^{\prime}\left|x^{\prime}\right\rangle\left\langle x^{\prime}\right| \hat{x} \hat{x}(\Delta x)\left|x^{\prime}\right\rangle\left\langle x^{\prime} \mid \psi\right\rangle-\hat{T}(\Delta x) \hat{x}\left|x^{\prime}\right\rangle\left\langle x^{\prime}\right\rangle\left\langle x^{\prime} \mid \psi\right\rangle\right) \\
#
# = & \int d x^{\prime} \hat{x}\left|x^{\prime}+\Delta x\right\rangle\left\langle x^{\prime} \mid \psi\right\rangle-x^{\prime} \hat{T}(\Delta x)\left|x^{\prime}\right\rangle\left(x^{\prime}|\psi\rangle\right) \\
#
# = & \int d x^{\prime}\left(x^{\prime}+\Delta x\right)\left|x^{\prime}+\Delta x\right\rangle\langle x \mid \psi\rangle-x^{\prime}\left|x^{\prime}+\Delta x\right\rangle\left\langle x^{\prime} \mid \psi\right\rangle \\
#
# = & \Delta x \int d x^{\prime}\left|x^{\prime}+\Delta x\right\rangle\left\langle x^{\prime} \mid \psi\right\rangle \\
#
# = & \Delta x \hat{T}(\Delta x) \int d x^{\prime}\left|x^{\prime}\right\rangle\left\langle x^{\prime} \mid \psi\right\rangle \\
#
# & =\Delta x \hat{T}(\Delta x)|\psi\rangle
# $$
# $$
#
# Since this expression will be valid for all $|\psi\rangle$we infer.
# By dividing with$\quad[\hat{x}, \hat{T}(\Delta x)]=\hat{T}(\Delta x) \cdot \Delta x
# $$
#
# $$
# \frac{1}{\Delta x}[\hat{x}, \hat{T}(\Delta x)]=T(\Delta x)
# $$
#
#
# Now we remember the relation: $\hat{T}(\Delta x)=\hat{I}-\hat{i} \Delta x \hat{P}$ and insert in the abele expression
#
# $$
# $$
# & \frac{1}{\Delta x}[\hat{x}, \hat{T}(\Delta x)]=\frac{1}{\Delta x}\left[\hat{x}, I-\frac{i}{\hbar} \Delta x \hat{P}\right]=I-\frac{i}{\hbar} \Delta x \hat{P} \\
#
# & \underbrace{\frac{1}{\Delta x}[\hat{x}, \hat{I}]-\frac{i}{\hbar}[\hat{x}, \hat{P}]=I-\frac{1}{\hbar} \Delta x \hat{P}+\cdots}_0 \\
#
# & \underbrace{\hbar \hat{x}}_0, \hat{P}]=-\frac{\hbar}{i}+\Delta x \hat{P}+\theta\left(\Delta x^2\right)+\cdots
# $$
# $$
#
# $$
# \lim$ leads to
# $$
# \Delta x \rightarrow 0
# $$
#
# $$
# [\hat{x}, \hat{p}]=i \hbar
# $$
#
#
# We have shown that $\hat{x}$and$\hat{p}$are incompatible observalles! Historically, this relation has been found by Max Born right after Weer Heisenberg has introduced the matrix mechanics.
# The moncommutability of$\hat{X}$and$\hat{P}$means that there are no simultaneous eigenfunctions of$\hat{X}$and$\hat{P}$. There is no such thing as $|x, p\rangle$ so that
#
# $$
# $$
# & \hat{x}|x, p\rangle=x|x, p\rangle \\
#
# & \hat{p}|x, p\rangle=p|x, p\rangle
# $$
# $$
#
#
# But if $\hat{P}$is an observable, what ane the eigenstates of$\hat{p}$ ?
#
# $$
# \hat{p}|p\rangle=p|p\rangle
# $$
#
#
# Such eigenstate represents a physical state with a precisely determined momentum.
#
# How does the momentum eigenstate representation?
#
# $$
# \langle\hat{x}| \hat{p}|p\rangle=\frac{\hbar}{i} \frac{\partial}{\partial x}\langle x \mid p\rangle=p\langle x \mid p\rangle
# $$
#
#
# This is a first order differential equation which can le easily solved
#
# $$
# \langle x \mid p\rangle=\sqrt[N]{ } e^{\mid p x / \hbar}
# $$
#
# $$
# \mathcal{N}$is a normalization constant. The problem is that the momentum eigenstates comsat be moralized in a usual sense such that$\quad\langle p \mid p\rangle=1$.
# Instead in the analogy with position eigenstates we require the momention eigenstat's to be normalised such the
#
# $$
# $$
# & \left\langle p^{\prime} \mid p\right\rangle=\delta\left(p^{\prime}-p\right) \\
#
# & \left.|x|^2 \int d x e^{i\left(p-p^{\prime}\right) x / \hbar}=\delta\left(p^{\prime}-p\right) \int d p{ }^{\prime}\right) \\
#
# & |J|^2 \int d p^{\prime} d x c^{\prime}\left(p-p^{\prime}\right) x / \hbar=1
# $$
# $$
#
#
# In order to calculate the abe integral we first quantize the momentum, This can be achived by imposing periodic boundary conditions. This is equirdent to replacing an infinite lime by a circle with some ciroungence.
#
# Imposing periodic boundary condition means that
# spirally $\quad \psi(x+L)=\psi(x)
# $$
# for a momentum w eigenstate this means that
#
# $$
# $$
# & \langle x \mid p\rangle=\langle x+L / p\rangle \\
#
# & e^{i p x / h}=e^{i p(x+L) / \hbar} \Rightarrow e^{i p L / \hbar}=1
# $$
# $$
#
#
# From this it follows
#
# $$
# \frac{p L}{\hbar}=2 \pi n \Rightarrow p_n=\frac{2 \pi n}{L} \hbar
# $$
#
#
# Thus for a partide on a circle, the momentum n is quantized , and the momentum aigenstates read
#
# $$
# \left\langle x \mid p_n\right\rangle=N e^{i \frac{2 \pi n}{t} \hbar x}
# $$
#
#
# Such states are normalizable in a usual sense!
#
# $$
# \int_0^L d x\left\langle p_a \mid x\right\rangle\left\langle x \mid p_n\right\rangle=1 \Rightarrow N^2 L=1 \Rightarrow N=\frac{1}{\sqrt{L}}
# $$
#
#
# Thus the states:
#
# $$
# \left\langle x \mid p_n\right\rangle=\frac{1}{\sqrt{L}} e^{i \frac{2 \pi n \hbar}{L} x}
# $$
#
# are orthonormal
#
# $$
# \left\langle p_m \mid p_n\right\rangle=\int_{-\frac{L}{2}}^{\frac{L}{L}} d x\left\langle p_m \mid x\right\rangle\left\langle x \mid p_n\right\rangle=\delta_{m \omega}
# $$
#
#
# From
# $$
# \left\langle p_m \mid p_n\right\rangle=\delta_{m n}$ it fallows
#
# $$
# $$
# & \sum_m\left\langle p_m \mid p_n\right\rangle=\sum_m \delta_{m n}=1 \\
#
# & \sum_m \int_{-\frac{L}{2}}^{\frac{L}{2}} d x\left\langle p_m \mid x\right\rangle\left\langle x \mid p_n\right\rangle=1
# $$
# $$
#
#
# $$
# $$
# & \sum_m \int_{-L}^{L / L} d x \frac{1}{L} e^{-\frac{i 2 \pi(m-n) \hbar x}{L}}=1 \\
#
# & \frac{1}{2 \pi \hbar} \sum_m^2 \frac{2 \pi \hbar}{L} \int_{-\frac{L}{2}}^{\frac{L}{2}} e^{-i} \frac{2 \pi \hbar}{L}(m-n) \times=1 \\
#
# & \text { Fur } \quad L \rightarrow \infty \quad \Delta p=\frac{2 \pi t}{L} \Rightarrow 0 \\
#
# & \frac{1}{2 \pi \hbar} \iint d p^{\prime} d x e^{i\left(p^{\prime}-p\right) x / \hbar}=1 \\
#
# & \int_{-\infty}^{+\infty} d p^{\prime}\left[\frac{1}{2 \pi \hbar} \int_{-\infty}^{+\infty} e^{i^{\prime}\left(p^{\prime}-p\right) / \hbar} d x\right]=1 \\
#
# & \delta\left(p^{\prime}-p\right)=\frac{1}{2 \pi \hbar} \int d x e^i(p-p) x / \hbar \\
#
# & \delta\left(p^{\prime}-p\right)=\int d x \frac{e^{i p^{\prime} x / \hbar}}{\sqrt{2 \pi \hbar}} \frac{e^{-i p x / \hbar}}{\sqrt{2 \pi \hbar}} \\
#
# & \left\langle x \mid p^{\prime}\right\rangle \quad\langle p \mid x\rangle
# $$
# $$
#
#
# So we can identify:
#
# $$
# \left\langle\langle x \mid p\rangle=\frac{1}{\sqrt{2 \pi \hbar}} e^{i p x / \hbar}\right.
# $$
#
#
# This is a fundamental relation allowing us to switch between the position and the momentum representation for amy quantum state!
#
# Position and Momentum Representation
# We have now two operators $\hat{x}$and$\hat{p}$ whose corresponding eigenfunction build a complete sets
#
# $$
# $$
# & \hat{I}=\int d x|x\rangle\langle x| \\
#
# & \hat{I}=\int d p|p\rangle\langle p|
# $$
# $$
#
#
# We can now represent any quantum state either in the position or on the momentum basis
#
# $$
# $$
# & |\psi\rangle=\int d x|x\rangle\langle x \mid \psi\rangle \\
#
# & |\psi\rangle=\int d p|p\rangle\langle p \mid \psi\rangle
# $$
# $$
#
# $$
# \langle x \mid \psi\rangle$is defined as a position representation of the quanturn state$|\psi\rangle$and it is usually denoted by$\psi(x)$.
# $$
# \langle p \mid \psi\rangle$is defined as a momentum representation of the quantum/ state$|\psi\rangle$and is denoted by$\phi(p)$.
# We mow answer the following question. Given $\psi(x)$, how can we get $\phi(p)$ and vice vera?
#
# $$
# $$
# \phi(p)=\langle p \mid \psi\rangle & =\langle p| \hat{I}|\psi\rangle=\int d x\langle p \mid x\rangle\langle x \mid \psi\rangle \\
#
# & =\frac{1}{\sqrt{2 \pi h}} \int d x e^{-i p x / \hbar} \psi(x)
# $$
# $$
#
#
# Thus,
#
# $$
# \phi(p)=\frac{1}{\sqrt{2 \pi \hbar}} \int_{-\infty}^{+\infty} \psi(x) e^{-i p x / \hbar}
# $$
#
#
# The transformation works also in the oposite direction!
#
# $$
# $$
# \psi(x)=\langle x \mid \psi\rangle & =\langle x| \hat{I}|\psi\rangle=\int d p\langle x \mid p\rangle\langle p \mid \psi\rangle \\
#
# & =\frac{1}{\sqrt{2 \pi \hbar}} \int_{-\infty}^{+\infty} d p \phi(p) e^{i p^x / \hbar}
# $$
# $$
#
# So we obtain the
#
# $$
# $$
# & \phi(p)=\frac{1}{\sqrt{2 \pi \hbar}} \int_{-\infty}^{+\infty} \psi(x) e^{-i p x / \hbar} d x \\
#
# & \psi(x)=\frac{1}{\sqrt{2 \pi \hbar}} \int_{-\infty}^{+\infty} \phi(p) e^{i p^x / \hbar} d p
# $$
# $$
#
#
# Example:
# We consider a step function:
#
# $$
# \psi(x)=
# $$
# 0 & |x|>\frac{1}{2} a \\
#  c & |x| \leqslant \frac{1}{2} a
# $$
# $$
#
#
# We first normalise the function such that.
#
# $$
# $$
# & \int_{-\infty}^{+\infty}|\psi(x)|^2 d x=1 \\
#
# & \int_{-\frac{1}{2} a}^{+\frac{1}{2} a}|c|^2 d x=1 \Rightarrow|a|^2 \cdot a=1 \Rightarrow|c|=\frac{1}{\sqrt{a}}
# $$
# $$
#
#
# Thus, moralized function reads
#
# $$
# \psi(x)=
# $$
# 0 & |x|>\frac{1}{2} a \\
#  \frac{1}{\sqrt{a}} & |x| \leqslant \frac{1}{2} a
# $$
# $$
#
# In the joucowing we calculate the momentum space representation of such quantum state
#
# $$
# $$
# & \langle p \mid \psi\rangle=\int d x\langle p \mid x\rangle\langle x \mid \psi\rangle \\
#
# & \frac{1}{\sqrt{2 \pi \hbar}} e^{-i p x / \hbar} \\
#
# & =\frac{1}{\sqrt{2 \pi \hbar}} \int_{-\infty}^{+\infty} d x \psi(x) e^{-i p x / \hbar} \\
#
# & =\frac{1}{\sqrt{2 \pi \hbar}} \int_{-\infty}^{+\infty} d x \psi(x) e^{-i p x / \hbar} \\
#
# & =\frac{1}{\sqrt{2 \pi \hbar}} \int_{-\frac{a}{2}}^{\frac{a}{2}} d x \frac{1}{\sqrt{a}}-e^{i p x / t} \\
#
# & =\frac{1}{\sqrt{2 a \pi \hbar}}\left[\left.\frac{-\hbar}{i p} e^{-i p x / \hbar}\right|_{-a / 2} ^{a / 2}\right] \\
#
# & =\frac{2 \hbar}{\sqrt{2 a \pi \hbar}}\left[\frac{e^{i p a / 2 \hbar}-e^{-i p a / 2 \hbar}}{2 i p}\right] \\
#
# & =\frac{2 \hbar}{\sqrt{2 a \pi t}} \cdot \frac{1}{p} \cdot \sin \left(\frac{p a}{2 \hbar}\right) \\
#
# & =\sqrt{\frac{2 \hbar}{a \pi}} \cdot \frac{1}{p} \sin \left(\frac{p a}{2 \hbar}\right)
# $$
# $$
#
# Ne see that the state
# between $-\frac{a}{2}$and$\frac{a}{2}$. In the momentum space, the same state is mat perfectly localized. However, we can roughly define the width of the state on the momentum spare as a separation between the first two zero pants
#
# $$
# $$
# & \sin \left(\frac{p a}{2 \hbar}\right)=0 \\
#
# & \frac{p a}{2 \hbar}= \pm \frac{\pi}{2} \\
#
# & p= \pm \frac{\pi \hbar}{a}
# $$
# $$
#
#
# So we see that $\Delta p \sim \frac{2 \pi \hbar}{a}
# $$
# From this we can derive a special form of the Heisenberg's uncertainty relation:
#
# $$
# \Delta x \cdot \Delta p=\alpha \cdot \frac{2 \pi \hbar}{a}=2 \pi \hbar
# $$
#
#
# Which tells us that the product of uncerntannties in $x$and$p$is of the order of$\hbar$ !
#
# $$
# \Delta x \Delta p \sim t
# $$
#
#
# Example 2
# How does the ground state of a harmonic oscillator look like?
